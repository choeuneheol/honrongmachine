# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuneheol/honrongmachine/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D%EA%B8%B0%EC%B4%88Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 15th
#
# 기대값은 어떤 사건이 일어날 가능성
#
# 가치에서 음수가 나올수가 있다.
#
# 내가만든 모델을 만들었을때 누가 이득을 볼수가 있을까?

# %% [markdown]
# 16th
#
# 생태계 모방 알고리즘
#
# 휴리스틱 적인 방향으로 가도되지만 근거가 어느정도 있어야한다
#
# 세대를 거쳐서 내려가게되는데 우성을 전달하게된다
#
# Genotype 0과1의 로 이루어진 데이터 컴퓨터가 보는 데이터
#
# phenotype 표현형 사람이 보는 데이터
#
# 진화가 계속 이뤄지기 때문에 스탑조건을 꼭 걸어줘야한다
#
# 돌연변이 연산을 하면
#
# 로컬미니마를 하는 작용을 하며 살짝 결과가 떨어질 수 있다
#
# 엘리티즘 좋은걸 많이 뽑는것 1등은 바로 다음세대로 보내버리기
#
# 진화가 빨리 이루어지면 데이터가 대충만들어 질 경우가 있다
#
# 문제에 대한 제약조건이 적고 응용범위가 넓다
#
# 학습이랑 최적회쪽에서는 좋다
#
# 수학적인 부분이 약한 분석가가 하면 좋게 나오지 않는다

# %% [markdown]
# 17th
#
# 사례연구 및 비즈니스 전략
#
# 컴텍이 망한이유
#
# 데이터를 일반적으로 모았다
#
# 델은 데이터를 모아서
#
# 온라인판매를 시작하여 성공하였다

# %% [markdown]
# Deep Learning
#
# 그전까지 사람이 개입했어야했는데 이제는
#
# 사람이 개입하지 않는다 자동화 시켜서 성능개선을 한다
#
# 오차함수, 손실함수, 목적함수는 같은 이야기를 하는 말이다
#
# 오차를 계산하려고 하는 함수들이다
#
# 스칼라는 양만
#
# 벡터는 열벡터 벡터라이즈한다
#
# 벡터라는 말은 행으로 데이터를 열로 바꾸었다라고 생각하면된다
#
# 벡터가 나오면 행렬식이 붙는다
#
# 앞에 있는 행과 뒤에 있는 행이 같아야하기 떄문에 벡터를 계산한다
#
# 계층확률 추정이 반드시 필요하다
#
# 만들어진 모델은 현업에서 누가 사용하는가?
#
# 비즈니스 분야로 한정 시 예측모델 중 분류모델 선호
#
# 분류 모델 생성 후 개별 인스턴스의 계층확률 추정 필요
#
# 모델은 반드시 객관성 담보가 필요
#
#  -모델 -> 목적달성을 위해 현실세계를 단순하게 표현한 것
#
# 예측모델을 어떻게 만들 것인가?
#
# 다양한 방법이 존재
#
#  - 데이터를 읽어가며 모델 생성 - 딕션트리
#
#  - 모델을 먼저 결정하고 데이터에 맞춤 - 선형분류모델
#
# 모수적 접근 - 이것은 통계학적으로 접근하겠다
#
# 데이터의 분포가 제대로 되어있어야한다
#
# 모수-파라미터
#
# 비모수적- 데이터나 머신러닝쪽으로 사용하겠다는 이야기
#
# 상수값을 찾아내는 러닝 -선형분류모델
#
# 머신러닝때는 산점도를 그리면(선을 그리면) 대략적인 분포도가 보인다
#
# wait some 가중치값
#
# 점진적으로 접근한다는 것은 오차를 줄이는 방식으로 접근한다
#
# 오차는 e=t-m

# %% [markdown]
# 2th
#
# 싱글 레이어 퍼셉트론
#
# 딥러닝 들어가기전에 선형분류모델을 꼭 알아야한다 그래서 복습!
#
# 상수값을 찾아내는 러닝 -선형분류모델
#
# 머신러닝때는 산점도를 그리면(선을 그리면) 대략적인 분포도가 보인다
#
# wait some 가중치값
#
# 점진적으로 접근한다는 것은 오차를 줄이는 방식으로 접근한다
#
# 오차는 e=t-m
#
# Threshold - 어떤 값이 활성화 되기 위한 최소값
#
# 문턱을 넘어서면 상태가 바뀐다
#
# Weight - 선형분류모델의 기울기
#
# 기울기와 절편 찾는 것이다
#
# Bias - 선형분류를 위한 직선의 절편
#
# Neuron - 인공신경망의 가장 작은 요소
#
# 활성함수 - 쓰레스홀드 한계점이 넘어가면 발동하는 함수
#
# 퍼셉트론은 이진분류만 나온다
#
# 가중치와 바이어스 가중치 -> -0.5와 0.5 사이의 임의의 값
#
# 바이어스 입력 값 -> -1 또는 1로 초기화
#
# 뉴런의 net값을 활성함수에 넣음
#
# 데이터를 다맞출때가지 다시 계속하는 것을 반복하는 것을 Epoch
#
# 퍼셉트론의 스탑조건 내가만든 모델이랑 다같아야 스탑
#
# 이진분류이상은 신경망으로 넘어가야한다
#
# 어디선가 스텝펑션을 들었다면 퍼셉트론을 쓴다는걸로 알면된다

# %% [markdown]
# 0장
#
# 변수를 쓰는 가장큰 목적
#
# 데이터를 계속 사용하겠다는 의미
#
# 변수-데이터를 저장하기위해 메모리공간에 붙여진이름
#
# 상수는 데이터를 저장하기위해 메모리공간에 붙여진이름
#
# 이지만 변경할수없다 이름이 없는 상수를 리터럴이라한다
#
# 관계연산자는 결과가 항상 True나 False로 나오는것 주의!!
#
# 논리연산자는 True, False 첫글자는 대문자 주의!!
#
# 선택과 반복을 해야한다
#
# 내가구현하려는 대상에 대해서 속성과 기능에 대해서
#
# 주소값을 받아주는 타입 레퍼런스타입

# %%
3th

미분의 상대적 변화량
