# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuneheol/honrongmachine/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D%EA%B8%B0%EC%B4%88_DAY4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6월 3일 9시 1교시 어제한것 복습
#
# 8th
#
# 상수값을 찾아주는 파라미터 러닝
#
# 사람은 생각이라는걸 하는데
#
# 컴푸터는 생각을 못하는데 연산을 잘한다
#
# 내가만든모델의출력값 - M
#
# 실제값 - T
#
# 오차 - E
#
# 산점도?
#
# 산포도?
#
# 오차를 가지고 델타a를 구할수있나?
# E= t-y
#
#  =(a+델타a)x - ax
#
#  =ax+델타x-ax
#
#  =델타x
#
#  =델타a=e/x
#
# 선형분류모델은 마지막데이터의 영향력이 크다
#
# 마지막데이터를 바꿔가며 여러번 돌린다
#
# 학습률은 자동화를 하였을때 선의움직이는 격차를 줄여줌
#
# 9
# 리니어 리그레이션 선형회귀
#
# 확률추정
#
# 타겟벨류에 수치형데이터가 들어어ㅗ
#
# 내가 알고 싶은값이 숫자값
#
# 숫자값을 예측하고 싶다
#
# 식이 선형분류모델과 같다
#
# 근데 목적이 다르다
#
# 선을 그려서 추세를 본다
#
# 타이어 사용량 = y
#
# 총 운행거리 = x
#
# 자격증 시험을 보기위해선 수식
#
# 절대값 1에 가까우면 ...
#
# 음수양수 다된다
#
# 회귀분석도 성능평가를 받아야한다
#
# RMSE 현업에서 많이 이야기나온다
#
#
#
# 10 2교시
#
# 로지스틱 회귀분석
#
# 숫자를 가지고 분류문제를 푼다
#
# 계산이 끝났을때 숫자가 나오는데
#
# 그숫자는 확률이 나온다
#
# 확률이 크면 a
#
# 작으면 b

# %% [markdown]
# ### 12th phase
# Similarity, Neighbors, and Clusters

# %% [markdown]
# 유사도
#
# 비즈니스 문제에서 유사도는 데이터분석 기법과 함께 중요한
#
# 해결책의 기반이 됨
#
# 비즈니스 사례
#
# IBM
#
# 영업부에서 잠재고객을 찾기 위해 우수 고객과 유사한 회사찾음
#
# HP
#
# 많은 고객 사의 서버를 유지보수
#
# 어느 서버 환경 설정이 가장 좋은 성능을 내는지 찾음
#
# 아마존 or 넷플릭스
#
# 유사도 측정
#
# 유사도의 정의
#
# 데이터 간의 유사도 측정필요
#
# 특징을 정의하는 공간에서 가까울수록 두 객체는 비슷
#
# 유사하다는 근거 -> 거리
#
# 거리
#
# 데이터와 데이터 간의 거리는 어떻게 측정?

# %% [markdown]
# 비지니스에 많이 쓰이고 있다. IBM왓슨이
#
# 길병원 암센터에 왔는데 수술에대해 제의에서 왓슨이 이기고 있다
#
# 알파고는 바둑만두지만 ibm왓슨은 이미 실용에 쓰이고 있다
#
# 데이터와 데이터 사이의거리를 잼
#
# 거리를 어찌 측정하냐?
#
# 유클리드 거리를 쓰면된다
#
# 피쳐가 xy 두개밖에 안된다
#
# 유클리드 두식밖에 없지만 임의로 뒤에 식을 늘린다
#
# KNN 알고리즘 슈퍼바이저 러닝
#
# KNN - 최근접 이웃 추론, k명의 가까운 것을 봐라
#
# 수치형데이터로 전처리 해야한다
#
# 샘플의 갯수가 작을때는 홀수로 잡아야한다
# 샘플의 갯수가 클때는 짝수로 잡아도 된다
#
# 수치형분석은 회귀분석...
#
# k가 작아지면 오버피팅이 일어남
# k가 크면 언더 피팅이 일어남 언더 피팅은 단순하게 나온다는걸 말함
#
# 가중치가 적용된 확률
#
# 거리가 가까울수록 확률을 올려주고
# 거리가 멀수록 확률을 내려주는 알고리즘 knn
#
#
#
# 클러스터링 언슈퍼바이저 러닝
#
# 계층적 군집분석
#
# 계층적 군집분석으로 클러스터를 묶었을때
#
# 묶이는 것들을 파악할 수 있다
#
# 마지막엔 하나로 묶인다
#
# k는 가장 가까운 이웃들의 수
#
# 디스토션? 왜곡값
#
# 실루엣 스코어나 디스토션을 정해서 k평균 군집화를 반복을 멈춘다
#
# 클러스터가 많아질수록 왜곡값이 줄어드는데
#
# 디스토션 왜곡값이 완만해질때가 있는데 엘보메서드
#
# 각각의 챕터 다큐먼트
#
# 단어가 모여서 다큐먼트  문서가 모여서 토큰   책이 커퍼스 말뭉치?
#
# 다큐먼트 안에서 나오는 빈발하게 나오는 것은 주제어가 될 가능성이 높다
#
# 문서안에서는 희박하게 나오는데 커퍼스안에서빈발하게 나오는 것을 주제어로 본다
#
# 문서안에서는 희박하게 나오는것을 TF
#
# 역문서빈발도...
#
# 인포메이션게인과 흡사한부분이 있다

# %% [markdown]
# 14th Phase
# Bayes Rule
# 집에 도둑들이다들어와서 다털어갔는데
# 역으로 집에 들어와서 집에 털어갔나 들어오는 언어
#
# 확률표시할때 막대기가 그어져있으면   뒤에있는아이가 주어졌을때 앞에 있는아이가 발생할 확률
#
# 뒤에있는게 주어졌을때 앞에 있는게 발생할 확률
#
# 이산데이터 샐수 있는 데이터
#
# 대문자는 셀수있는 데이터
#
# 소문자에는 촘촘하게 있는 데이터를 연속데이터
#
# 얼마/전체 = 확률
#
# 분모가 무한대로 나오기 떄문에
#
# 구간을 잡아놓고 면적을 구한다
#
# 사전확률, 조건부확률, 결합확률, 주변확률 파악하기
#
#
# 하나를 적엇는데 이벤트 앞단을 물어보면 사전확률
# 뒷단을 물어보면 주변확률
#
#
#  확률 문제
#  스팸필터
#
#  전체 메일의 80%가 스팸
#  95% 스팸메일에서 "대출"발견
#  정상메일의 2% 에서도 "대출" 발견
#  현재 "대출" 이라는 글을 봤다면 스팸확률은?

# %% [markdown]
# 15
#
# 예측의 분류모델 중에 문제를 풀어조는 모델
# 디시즌트리
# 선형회귀모델
# KNN
# 베이즈
# 로지스틱회귀모델
#
# 에러는 기본적으로 작을수록 좋다
#
# 범주형이라는것은 예측의 분류모델을 푸는 모델인데
#
# 잘푸는 모델이 좋은데 그 모델을 평가하는 방법으로
#
# 공학적으로푸는 방법이 있다
#
# 모델을 평가할때 고려할때
#
# 리스크와 코스트... 비용
#
# 리스크와 코스트는 모델을 평가할때 쓰인다
#
# 성능을 평가할때 그려야하는 표
#
# 혼동행렬을 반드시 그려야한다
#
# 행 정보는 내가만든 모델의 결과값
#
# 포지티브 네거티브는 타겟벨류
#
# 리콜에 False가 작어야 좋다
#
# 혼동행렬에서 기준은 내가 만든 모델의 값
