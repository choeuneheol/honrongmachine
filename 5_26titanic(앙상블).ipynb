# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuneheol/honrongmachine/blob/main/5_26titanic(%EC%95%99%EC%83%81%EB%B8%94).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train_df=pd.read_csv("/content/train.csv")
test_df=pd.read_csv("/content/test.csv")

# %% [markdown]
# ##트레인데이터 전처리

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df = train_df.drop(['Name'],axis=1)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_df2 = train_df.iloc[:,1:4]

# %%
df3=pd.DataFrame(train_df2)

# %%
train_df2
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
df3
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
df3.dropna().describe()
# Out:
#          Survived      Pclass
# count  891.000000  891.000000
# mean     0.383838    2.308642
# std      0.486592    0.836071
# min      0.000000    1.000000
# 25%      0.000000    2.000000
# 50%      0.000000    3.000000
# 75%      1.000000    3.000000
# max      1.000000    3.000000

# %%
df3.groupby('Pclass').count()
# Out:
#         Survived  Sex
# Pclass
# 1            216  216
# 2            184  184
# 3            491  491

# %%
sns.countplot(y='Pclass',data=df3)

# %%
sns.countplot(y='Sex',data=df3)

# %%
sns.countplot(y='Survived', data=df3)

# %%
df3.pivot_table('Survived',index='Pclass',columns='Sex')
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
sns.catplot(x='Pclass',y='Survived',
            hue='Sex', data=df3)

# %%
X = pd.get_dummies(df3) #One-hot Encoding
Y = df3['Pclass']

# %%
df4=pd.get_dummies(df3)

# %%
df4
# Out:
#      Survived  Pclass  Sex_female  Sex_male
# 0           0       3           0         1
# 1           1       1           1         0
# 2           1       3           1         0
# 3           1       1           1         0
# 4           0       3           0         1
# ..        ...     ...         ...       ...
# 886         0       2           0         1
# 887         1       1           1         0
# 888         0       3           1         0
# 889         1       1           0         1
# 890         0       3           0         1
#
# [891 rows x 4 columns]

# %%
from os import replace
df3[replace]
# Out:
#      Survived  Pclass  Sex_female  Sex_male
# 0           0       3           0         1
# 1           1       1           1         0
# 2           1       3           1         0
# 3           1       1           1         0
# 4           0       3           0         1
# ..        ...     ...         ...       ...
# 886         0       2           0         1
# 887         1       1           1         0
# 888         0       3           1         0
# 889         1       1           0         1
# 890         0       3           0         1
#
# [891 rows x 4 columns]

# %%
input_data = df4[['Pclass','Sex_female']].to_numpy()
target = df4['Survived'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=400)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (712, 4)
# (179, 4)
# (712,)
# (179,)

# %%
model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_train_pred = model.predict(X_train) # 알고리즘이 학습을 얼마나 잘 시켰는가?
Y_test_pred = model.predict(X_test) # 새로운 데이터가 들어올 때, 얼마나 좋은 성능을 나타내는가

# %%
print(classification_report(Y_train,Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       182
#            2       1.00      1.00      1.00       143
#            3       1.00      1.00      1.00       387
#
#     accuracy                           1.00       712
#    macro avg       1.00      1.00      1.00       712
# weighted avg       1.00      1.00      1.00       712

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        41
#            3       1.00      1.00      1.00       104
#
#     accuracy                           1.00       179
#    macro avg       1.00      1.00      1.00       179
# weighted avg       1.00      1.00      1.00       179

# %% [markdown]
# ##테스트데이터 전처리

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
td2=test_df.iloc[:,1:4].drop(columns=['Name'])

# %%
td2
# Out:
#      Pclass     Sex
# 0         3    male
# 1         3  female
# 2         2    male
# 3         3    male
# 4         3  female
# ..      ...     ...
# 413       3    male
# 414       1  female
# 415       3    male
# 416       3    male
# 417       3    male
#
# [418 rows x 2 columns]

# %%
sns.countplot(y='Sex',data=td2)

# %%
sns.countplot(y='Pclass',data=td2)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
td2 = pd.get_dummies(td2)

# %%
model.predict(td2)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - Survived
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-43ed9372a974> in <module>()
# ----> 1 model.predict(td2)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
# ...

# %%
td2
# Out:
#      Pclass  Sex_female  Sex_male
# 0         3           0         1
# 1         3           1         0
# 2         2           0         1
# 3         3           0         1
# 4         3           1         0
# ..      ...         ...       ...
# 413       3           0         1
# 414       1           1         0
# 415       3           0         1
# 416       3           0         1
# 417       3           0         1
#
# [418 rows x 3 columns]

# %% [markdown]
# ## 앙상블학습

# %%
rf = RandomForestClassifier(n_jobs=-1, random_state=42)
scores = cross_validate(rf, input_data, target,
                        return_train_score=True, n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))
# Out:
# 0.7901252028932978 0.773316176009039
